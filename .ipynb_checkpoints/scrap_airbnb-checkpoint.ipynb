# %%
from bs4 import BeautifulSoup
import requests
import re

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36', 
    'Accept-Language':'en-GB, en; q=0.5',
    'Referer':'https://google.com',
    'DNT':'1'}
url = 'https://www.airbnb.com.br/s/Italia/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&price_filter_input_type=0&price_filter_num_nights=5&query=Italia&place_id=ChIJA9KNRIL-1BIRb15jJFz1LOI&date_picker_type=calendar&checkin=2023-03-09&checkout=2023-04-09&adults=1&source=structured_search_input_header&search_type=autocomplete_click'
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
a = soup.find_all('div', {'class':'c4mnd7m dir dir-ltr'})
b = soup.find_all('div', {'class':'m1cp3yuo dir dir-ltr'})
c = soup.find_all('div', {'class':'dir dir-ltr'})
d = soup.find_all('div', {'class':'awuxh4x dir dir-ltr'})
e = soup.find_all('div', {'class':'cw9aemg dir dir-ltr'})
f = soup.find_all('div', {'class':'g1wiliwt cb4nyux dir dir-ltr'})
g = soup.find_all('div', {'class':'a3g92ry dir dir-ltr'})
h = soup.find_all('div', {'class':'f15liw5s dir dir-ltr'})
i = soup.find_all('div', {'class':'f15liw5s dir dir-ltr'})
j = soup.find_all('div', {'class':'pc0djro dir dir-ltr'})
k = soup.find_all('div', {'class':'g1qv1ctd cb4nyux dir dir-ltr'})
l = soup.find_all('div', {'class':'t1jojoys dir dir-ltr'})
m = soup.find_all("div", {"class":"nquyp1l s1cjsi4j dir dir-ltr"})
n = soup.find_all("div", {"class":"phbjkf1 dir dir-ltr"})

# %%
airbnb = soup.find_all("div", {"class":re.compile('dir dir-ltr')})
anuncios_airbnb = {'descrição':[], 'cidade':[], 'preço':[]}
for anuncio in airbnb:
    desc = anuncio.find('div', class_=re.compile('t1jojoys'))
    cida = anuncio.find('div', class_=re.compile('nquyp1l s1cjsi4j'))
    prec = anuncio.find('div', class_=re.compile('phbjkf1'))
    
    anuncios_airbnb['descrição'].append(desc)
    anuncios_airbnb['cidade'].append(cida)
    anuncios_airbnb['preço'].append(prec)

    print(desc, cida, prec)
# Out:
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# None None None
# ...

# %%
df = pd.DataFrame(dic_produtos)
df.to_csv('airbnb_it.csv', encoding='utf-8', sep=';')

# %%
#Ver todas as classes do html:
# class_list = set()
# tags = {tag.name for tag in soup.find_all()}
# for tag in tags:
#     for i in soup.find_all(tag):
#         if i.has_attr("class"):
#             class_list.add(" ".join(i['class']))
# classes = list(class_list)

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36', 
    'Accept-Language':'en-GB, en; q=0.5',
    'Referer':'https://google.com',
    'DNT':'1'}
url = 'https://www.amazon.com.br/s?k=python&__mk_pt_BR=%C3%85M%C3%85%C5%BD%C3%95%C3%91&crid=HJ2IO1WX2HYX&sprefix=pyth%2Caps%2C270&ref=nb_sb_noss_2'
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')

airbnb = soup.find_all("div", {"class":'a-section a-spacing-small puis-padding-left-small puis-padding-right-small'})
anuncios_airbnb = {'descrição':[], 'autor':[]}
for anuncio in airbnb:
    desc = anuncio.find('span', {'class':'a-size-base-plus a-color-base a-text-normal'}).get_text()
    auto = anuncio.find('span', {'class':'a-size-base'}).get_text()

    anuncios_airbnb['descrição'].append(desc)
    anuncios_airbnb['autor'].append(auto)

    print(desc)
# Out:
# Use a Cabeça! Python ― 2ª Edição
# Programação em Python 3
# Python Para Data Science: E Machine Learning Descomplicado
# Aprenda Python 3 do jeito certo: uma introdução muito simples ao incrível mundo dos computadores e da codificação
# Introdução à Programação com Python: Algoritmos e Lógica de Programação Para Iniciantes
# PYTHON: Learn Coding Programs with Python Programming and Master Data Analysis & Analytics, Data Science and Machine Learning with the Complete Crash Course ... Beginners - 5 Books in 1 (English Edition)
# Python Crash Course, 2nd Edition: A Hands-On, Project-Based Introduction to Programming
# Pense em Python: Pense Como um Cientista da Computação
# Fluent Python: Clear, Concise, and Effective Programming
# Python Crash Course, 3rd Edition (English Edition)
# Python e Mercado Financeiro: Programação Para Estudantes, Investidores e Analistas
# Começando a programar em Python para leigos
# ...

# %%
from selenium import webdriver

# %%
navegador = webdriver.Chrome()
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# C:\Users\BRUNOD~1\AppData\Local\Temp/ipykernel_12292/127006995.py in <module>
# ----> 1 navegador = webdriver.Chrome()
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      68             service = Service(executable_path, port, service_args, service_log_path)
#      69
# ---> 70         super(WebDriver, self).__init__(DesiredCapabilities.CHROME['browserName'], "goog",
#      71                                         port, options,
#      72                                         service_args, desired_capabilities,
#
# ...
